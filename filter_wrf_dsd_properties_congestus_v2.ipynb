# %%
#========================================================================
# Name: filter_wrf_dsd_properties_congestus.ipynb
# Author: McKenna W. Stanford
# Author Contact: mckenna.stanford@pnnl.gov
# Date Created: 05/22/2025
#
# Utility: Reads in CTH variables from derived files and pulls in the
# corresponding derived gamma dsd properties. Then limits the simulated
# dataset to the ridgeline, CTTs at least shallow enough to be considered
# congestus (i.e., > -25 deg C), and limits points in general to be above 0
# deg C.
#========================================================================

# %%
#===============================
# Imports
#===============================
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import glob
from matplotlib.collections import PatchCollection
from matplotlib.patches import Rectangle, Patch
from matplotlib.lines import Line2D
import matplotlib.gridspec as gridspec
import datetime
import matplotlib.colors as colors
import matplotlib as mpl
from pytz import utc
from matplotlib.lines import Line2D
import pickle
from scipy.spatial import cKDTree

import dask
from distributed import Client, LocalCluster
from dask import delayed, compute
import dask.array as da

import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.io.img_tiles as cimgt
import shapely.geometry as sgeom
import matplotlib.patheffects as path_effects

import warnings
warnings.filterwarnings("ignore")

plt.rcParams['text.usetex'] = True
# Out:
# /global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/pyproj/__init__.py:89: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()

# %%
path = '/pscratch/sd/m/mckenna/cacti/wrf/'
ct_files = sorted(glob.glob(path+'derived_3km/*.nc'))
dsd_files = sorted(glob.glob(path+'derived_3km_dsd_parameters/*.nc'))
num_ct_files = len(ct_files)
num_dsd_files = len(dsd_files)
print('# of cloud top files:',num_ct_files)
print('# of DSD files:',num_dsd_files)
# Out:
# # of cloud top files: 8794
# # of DSD files: 8794

# %%
ds = xr.open_dataset(ct_files[3600])
print(np.nanmax(ds['cth_tau_ir'].values))
print(np.nanmin(ds['cth_tau_ir'].values))
# Out:
# 4.487443359375
# 0.9868469848632813

# %% [markdown]
# # Need to get 3D WRF files as well, since I didn't save temperature

# %%
read_path = '/pscratch/sd/m/mckenna/'
file_name = read_path+'wrf_matched_file_lists.p'
with open(file_name, 'rb') as f:
    wrf_files_dict = pickle.load(f)
wrf_3d_files = wrf_files_dict['wrf_3d_files']
wrf_3d_datetimes = wrf_files_dict['wrf_3d_datetimes']

# %%
def subset_var_2d(data,mask):

    # mask values where the csapr mask == 0.
    masked_data = np.ma.masked_array(data, mask=mask == 0)

    # Extract the 2D subset defined by the mask
    # The unmasked elements will define the dimensions
    unmasked_data = masked_data[~masked_data.mask]  # Extract non-masked data


    row_indices, col_indices = np.where(~masked_data.mask)  # Get the unmasked indices

    new_rows = len(np.unique(row_indices))  # Number of unique rows in the unmasked region
    new_cols = len(np.unique(col_indices))  # Number of unique columns in the unmasked region

    reshaped_data = unmasked_data.reshape((new_rows, new_cols))

    return reshaped_data.data

# %%
def subset_var_3d(data,mask):

    nz = len(data[:,0,0])
    # mask values where the csapr mask == 0.
    reshaped_data_3d = []
    
    for kk in range(nz):
        data_2d = data[kk,:,:]
        masked_data = np.ma.masked_array(data_2d, mask=mask == 0)
        #print(aaaaa)
        
        # Extract the 2D subset defined by the mask
        # The unmasked elements will define the dimensions
        unmasked_data = masked_data[~masked_data.mask]  # Extract non-masked data
        
        
        row_indices, col_indices = np.where(~masked_data.mask)  # Get the unmasked indices
        
        new_rows = len(np.unique(row_indices))  # Number of unique rows in the unmasked region
        new_cols = len(np.unique(col_indices))  # Number of unique columns in the unmasked region
        
        reshaped_data = unmasked_data.reshape((new_rows, new_cols))
    
        reshaped_data_3d.append(reshaped_data.data)

    reshaped_data_3d = np.asarray(reshaped_data_3d)
    
    return reshaped_data_3d

# %%
def get_csapr_mask(wrf_ref_file, wrf_2d_file):
    # Open datasets
    ds_ref = xr.open_dataset(wrf_ref_file)
    lon_ref = ds_ref['XLONG'].squeeze().values
    lat_ref = ds_ref['XLAT'].squeeze().values
    ds_ref.close()

    ds_2d = xr.open_dataset(wrf_2d_file)
    lon_2d = ds_2d['CAC_LONG'].squeeze().values
    lat_2d = ds_2d['CAC_LAT'].squeeze().values
    ds_2d.close()

    # Flatten the 2D lat/lon arrays into a list of (lon, lat) points
    ref_points = np.column_stack((lon_ref.ravel(), lat_ref.ravel()))
    wrf_points = np.column_stack((lon_2d.ravel(), lat_2d.ravel()))

    # Build a KDTree from the reference WRF grid (fast spatial lookup)
    tree = cKDTree(ref_points)

    # Query the WRF 2D grid against the reference grid
    _, indices = tree.query(wrf_points, distance_upper_bound=1e-6)  # Use a small tolerance

    # Initialize mask with zeros
    csapr_mask = np.zeros_like(lon_2d, dtype=float)

    # Only mark valid matches (ignore out-of-bounds results)
    valid_matches = indices < ref_points.shape[0]
    csapr_mask.ravel()[valid_matches] = 1.0

    return csapr_mask,lon_2d,lat_2d

# %%
def get_terrain_height(csapr_mask):
    ter_path = '/global/cfs/projectdirs/m1657/avarble/cacti/wrf/output/2019-05-01/'
    ter_file = ter_path+'wrfout_d01_2019-05-01_00:00:00'
    ds_ter = xr.open_dataset(ter_file,engine='netcdf4')
    ter_hgt = ds_ter['HGT'].squeeze()
    ds_ter.close()
    ter_hgt = subset_var_2d(ter_hgt,csapr_mask)

    return ter_hgt

# %%
def trim_var(lon,lat,var,var_dim):
    lonmin = -64.95
    lonmax = -64.65
    latmin = -32.9
    latmax = -31.1
    
    mean_lon = np.mean(lon,axis=0)
    mean_lat = np.mean(lat,axis=1)  
    
    # Longitude
    trim_id = np.where( (mean_lon >= lonmin) & (mean_lon <= lonmax)  )[0]
    if var_dim == 2:
        var = var[:,trim_id]
    elif var_dim == 3:
        var = var[:,:,trim_id]

    # Latitude
    trim_id = np.where( (mean_lat >= latmin) & (mean_lat <= latmax)  )[0]
    if var_dim == 2:
        var = var[trim_id,:]
    elif var_dim == 3:
        var = var[:,trim_id,:]
        
    return var

# %% [markdown]
# # Get some static variables that are only needed once

# %%
#=======================
# Get height from different file
#=======================
read_path = '/pscratch/sd/m/mckenna/'
file_name = read_path+'wrf_matched_file_lists.p'
with open(file_name, 'rb') as f:
    wrf_files_dict = pickle.load(f)
    wrf_ref_files = wrf_files_dict['wrf_ref_files']
    wrf_2d_files = wrf_files_dict['wrf_2d_files']
ds_ref = xr.open_dataset(wrf_ref_files[0])
zamsl = ds_ref['ZAMSL'].values.squeeze()
ref = ds_ref['REFL_10CM'].values.squeeze()
col_max_ref = np.nanmax(ref,axis=0)
csapr_nan_mask = np.isnan(col_max_ref)
ds_ref.close()

nz,ny,nx = zamsl.shape
z_agl = np.zeros((nz,ny,nx))

csapr_mask,lon_2d,lat_2d = get_csapr_mask(wrf_ref_files[0],wrf_2d_files[0])
ter_hgt = get_terrain_height(csapr_mask)
for kk in range(nz):
    z_agl[kk,:,:] = zamsl[kk,:,:] - ter_hgt

np.savez("static_vars.npz",z_agl=z_agl,zamsl=zamsl,ter_hgt=ter_hgt,lon_2d=lon_2d,lat_2d=lat_2d,csapr_mask=csapr_mask,csapr_nan_mask=csapr_nan_mask)

# %% [markdown]
# # Serial Run

# %%
#for ii in range(3100,num_ct_files):
#for ii in range(3650,num_ct_files):
#for ii in range(3660,num_ct_files):

#for ii in range(num_ct_files):
for ii in range(3600,3601):

    ct_file = ct_files[ii]
    dsd_file = dsd_files[ii]
    print('CT file:',ct_file)
    print('DSD file:',dsd_file)
    ct_str = ct_file.split('/')[-1].split('.')[-2].split('_')[-2:]
    ct_date_str = ct_str[0]
    ct_time_str = ct_str[1].split(':')
    ct_year = int(ct_date_str[0:4])
    ct_month = int(ct_date_str[4:6])
    ct_day = int(ct_date_str[6:8])
    ct_hour = int(ct_time_str[0])
    ct_min = int(ct_time_str[1])
    ct_sec = int(ct_time_str[2])
    ct_datetime = datetime.datetime(ct_year,ct_month,ct_day,ct_hour,ct_min,ct_sec,tzinfo=datetime.timezone.utc)

    dsd_str = dsd_file.split('/')[-1].split('.')[-2].split('_')[-2:]
    dsd_date_str = dsd_str[0]
    dsd_time_str = dsd_str[1].split(':')
    dsd_year = int(dsd_date_str[0:4])
    dsd_month = int(dsd_date_str[4:6])
    dsd_day = int(dsd_date_str[6:8])
    dsd_hour = int(dsd_time_str[0])
    dsd_min = int(dsd_time_str[1])
    dsd_sec = int(dsd_time_str[2])
    dsd_datetime = datetime.datetime(dsd_year,dsd_month,dsd_day,dsd_hour,dsd_min,dsd_sec,tzinfo=datetime.timezone.utc)
    print('CT datetime:',ct_datetime)
    print('DSD datetime:',dsd_datetime)
    #print('Time:',dsd_datetime)

    if ct_datetime != dsd_datetime:
        raise RuntimeError('Times between cloud-top file and DSD file do not match...')


    static = np.load("static_vars.npz")
    z_agl = static["z_agl"]
    csapr_nan_mask = static['csapr_nan_mask']
    #zamsl = static["zamsl"]
    #csapr_mask = static["csapr_mask"]
    #lon_2d = static["lon_2d"]
    #lat_2d = static["lat_2d"]
    
    
    ds_ct = xr.open_dataset(ct_file)
    cth = ds_ct['cth_tau_ir'].values 
    cth = cth + (ter_hgt*1.e-3) # CTH was calculated using height AGL, but actually needs to be AMSL, so adding it back here
    #==============================================================================
    # Skip file entirely if entirely absent of cloud
    #==============================================================================
    if np.isnan(np.nanmax(cth)):
        ds_ct.close()
        print('Skipping file because no cloud present.')
        continue
    ctt = ds_ct['ctt_tau_ir'] 
    #==============================================================================
    # Skip file if the warmest CTT in the entire domain is colder than -25 deg C.
    #==============================================================================
    if np.nanmax(ctt) < -25.:
        ds_ct.close()
        print('Skipping file because warmest CTT is colder than -25 deg C.')
        continue
    lon = ds_ct['lon']
    lat = ds_ct['lat']
    ctt_dim = 2
    ctt_trim = trim_var(lon,lat,ctt,2)
    lon_trim = trim_var(lon,lat,lon,2)
    lat_trim = trim_var(lon,lat,lat,2)
    #==============================================================================
    # Skip file if warmest CTT in the trimmed domain is colder than -25 deg C.
    #==============================================================================
    if (np.nanmax(ctt_trim) < -25.) or (np.isnan(np.nanmax(ctt_trim))):
        ds_ct.close()
        print('Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.')
        continue
        
    # Read in other variables to be used for filtering
    lwp = ds_ct['lwp']
    twp = ds_ct['twp']
    iwp = ds_ct['iwp']
    #opd = ds_ct['opd_combined']
    opd = ds_ct['opd_vis']

    # Trim them
    lwp_trim = trim_var(lon,lat,lwp,2)
    twp_trim = trim_var(lon,lat,twp,2)
    iwp_trim = trim_var(lon,lat,iwp,2)
    opd_trim = trim_var(lon,lat,opd,2)
    cth_trim = trim_var(lon,lat,cth,2)
    ds_ct.close()

    #==============================================================================
    #==============================================================================
    # Now extract DSD parameters
    #==============================================================================
    #==============================================================================
    ds_dsd = xr.open_dataset(dsd_file)
    D_num = ds_dsd['D_num'] # m
    D_vol = ds_dsd['D_vol'] # m
    D_mass = ds_dsd['D_mass'] # m
    mmd = ds_dsd['mmd'] # m
    N = ds_dsd['N'] # kg^-1
    q = ds_dsd['q'] # kg/kg
    rho_air = ds_dsd['rho_air'] # kg/m^3
    #sigma_num = ds_dsd['sigma_num'] # m
    #skew_num = ds_dsd['skew_num'] # unitless
    #kurt_num = ds_dsd['kurt_num'] # unitless
    #sigma_mass = ds_dsd['sigma_mass'] # m
    #skew_mass = ds_dsd['skew_mass'] # unitless
    #kurt_mass = ds_dsd['kurt_mass'] # unitless
    N_0_r = ds_dsd['N_0_r'] # m^-4
    N_0_c = ds_dsd['N_0_c'] # m^-4
    lambda_r = ds_dsd['lambda_r'] # m^-1
    lambda_c = ds_dsd['lambda_c'] # m^-1
    mu_c = ds_dsd['mu_c'] # unitless
    q_gt_100um = ds_dsd['q_gt_100um'] # kg/kg
    N_gt_100um = ds_dsd['N_gt_100um'] # kg^-1
    ds_dsd.close()

    # NaN-out values that lie outside the CSAPR range
    D_num = D_num.where(~csapr_nan_mask)
    D_vol = D_vol.where(~csapr_nan_mask)
    D_mass = D_mass.where(~csapr_nan_mask)
    mmd = mmd.where(~csapr_nan_mask)
    N = N.where(~csapr_nan_mask)
    q = q.where(~csapr_nan_mask)
    rho_air = rho_air.where(~csapr_nan_mask)
    #sigma_num = sigma_num.where(~csapr_nan_mask)
    #skew_num = skew_num.where(~csapr_nan_mask)
    #kurt_num = kurt_num.where(~csapr_nan_mask)
    #sigma_mass = sigma_mass.where(~csapr_nan_mask)
    #skew_mass = skew_mass.where(~csapr_nan_mask)
    #kurt_mass = kurt_mass.where(~csapr_nan_mask)
    N_0_r = N_0_r.where(~csapr_nan_mask)
    N_0_c = N_0_c.where(~csapr_nan_mask)
    lambda_r = lambda_r.where(~csapr_nan_mask)
    lambda_c = lambda_c.where(~csapr_nan_mask)
    mu_c = mu_c.where(~csapr_nan_mask)
    q_gt_100um = q_gt_100um.where(~csapr_nan_mask)
    N_gt_100um = N_gt_100um.where(~csapr_nan_mask)

    D_num_trim = trim_var(lon,lat,D_num,3)
    D_vol_trim = trim_var(lon,lat,D_vol,3)
    D_mass_trim = trim_var(lon,lat,D_mass,3)
    mmd_trim = trim_var(lon,lat,mmd,3)
    N_trim = trim_var(lon,lat,N,3)
    q_trim = trim_var(lon,lat,q,3)
    rho_air_trim = trim_var(lon,lat,rho_air,3)
    #sigma_num_trim = trim_var(lon,lat,sigma_num,3)
    #skew_num_trim = trim_var(lon,lat,skew_num,3)
    #kurt_num_trim = trim_var(lon,lat,kurt_num,3)
    #sigma_mass_trim = trim_var(lon,lat,sigma_mass,3)
    #skew_mass_trim = trim_var(lon,lat,skew_mass,3)
    #kurt_mass_trim = trim_var(lon,lat,kurt_mass,3)
    N_0_r_trim = trim_var(lon,lat,N_0_r,3)
    N_0_c_trim = trim_var(lon,lat,N_0_c,3)
    lambda_r_trim = trim_var(lon,lat,lambda_r,3)
    lambda_c_trim = trim_var(lon,lat,lambda_c,3)
    mu_c_trim = trim_var(lon,lat,mu_c,3)
    q_gt_100um_trim = trim_var(lon,lat,q_gt_100um,3)
    N_gt_100um_trim = trim_var(lon,lat,N_gt_100um,3)

    #------------------------------------------
    # Get temperature
    # Also get Qr, Qc. Don't actually need these,
    # but they're helpful conceptually during testing.
    #------------------------------------------
    time_id = np.where(wrf_3d_datetimes == ct_datetime)
    if np.size(time_id) > 0.:
        time_id = time_id[0][0]
    else:
        raise RuntimeError('No matchting WRF 3D file.')
    ds_3d = xr.open_dataset(wrf_3d_files[time_id])
    temp = ds_3d['CAC_T'].squeeze() # K
    qr = ds_3d['CAC_QR'].squeeze()*1.e-3 # kg/kg
    qc = ds_3d['CAC_QC'].squeeze()*1.e-3 # kg/kg
    Nr = ds_3d['CAC_NR'].squeeze()*1.e-3 # kg/kg
    Nc = ds_3d['CAC_NC'].squeeze()*1.e-3 # kg/kg
    qv = ds_3d['CAC_QV'].squeeze()*1.e-3 # kg/kg
    pres = ds_3d['CAC_P'].squeeze() # Pa
    ds_3d.close()

    # Calculate RH
    C0 = 0.611583699e3
    C1 = 0.444606896e2
    C2 = 0.143177157e1
    C3 = 0.264224321e-1
    C4 = 0.299291081e-3
    C5 = 0.203154182e-5
    C6 = 0.702620698e-8
    C7 = 0.379534310e-11
    C8 = -0.321582393e-13
    X = temp.values - 273.15 # temperature in deg C
    ESL = C0 + X*(C1 + X*(C2 + X*(C3 + X*(C4 + X*(C5 + X*(C6 + X*(C7 + X*C8))))))) #saturation vapor pressure
    QVS = 0.622*ESL/(pres.values - ESL) #saturation vapor mixing ratio
    RH = 1e2*qv.values/QVS # %

    
    temp = subset_var_3d(temp,csapr_mask)
    RH = subset_var_3d(RH,csapr_mask)
    qr = subset_var_3d(qr,csapr_mask)
    qc = subset_var_3d(qc,csapr_mask)
    Nr = subset_var_3d(Nr,csapr_mask)
    Nc = subset_var_3d(Nc,csapr_mask)
    qr[:,csapr_nan_mask] = np.nan
    Nr[:,csapr_nan_mask] = np.nan
    qc[:,csapr_nan_mask] = np.nan
    Nc[:,csapr_nan_mask] = np.nan
    
    temp_trim = trim_var(lon,lat,temp,3)-273.15
    RH_trim = trim_var(lon,lat,RH,3)
    qr_trim = trim_var(lon,lat,qr,3)
    Nr_trim = trim_var(lon,lat,Nr,3)
    qc_trim = trim_var(lon,lat,qc,3)
    Nc_trim = trim_var(lon,lat,Nc,3)
    zamsl_trim = trim_var(lon,lat,zamsl,3)
    z_agl_trim = trim_var(lon,lat,z_agl,3)


    #------------------------------------------
    # Limit profiles to be under 10 km, as a start to limit memory
    #------------------------------------------
    zamsl_mean = np.mean(zamsl_trim,axis=(1,2))
    temp_mean = np.mean(temp_trim,axis=(1,2))
    height_id = np.where(zamsl_mean < 10000.)[0]

    temp_trim = temp_trim[height_id,:,:]
    RH_trim = RH_trim[height_id,:,:]
    qr_trim = qr_trim[height_id,:,:]
    Nr_trim = Nr_trim[height_id,:,:]
    qc_trim = qc_trim[height_id,:,:]
    Nc_trim = Nc_trim[height_id,:,:]
    zamsl_trim = zamsl_trim[height_id,:,:]
    z_agl_trim = z_agl_trim[height_id,:,:]
    D_num_trim = D_num_trim[height_id,:,:]
    D_vol_trim = D_vol_trim[height_id,:,:]
    D_mass_trim = D_mass_trim[height_id,:,:]
    mmd_trim = mmd_trim[height_id,:,:]
    N_trim = N_trim[height_id,:,:]
    q_trim = q_trim[height_id,:,:]
    rho_air_trim = rho_air_trim[height_id,:,:]
    #sigma_num_trim = sigma_num_trim[height_id,:,:]
    #skew_num_trim = skew_num_trim[height_id,:,:]
    #kurt_num_trim = kurt_num_trim[height_id,:,:]
    #sigma_mass_trim = sigma_mass_trim[height_id,:,:]
    #skew_mass_trim = skew_mass_trim[height_id,:,:]
    #kurt_mass_trim = kurt_mass_trim[height_id,:,:]
    N_0_r_trim = N_0_r_trim[height_id,:,:]
    N_0_c_trim = N_0_c_trim[height_id,:,:]
    lambda_r_trim = lambda_r_trim[height_id,:,:]
    lambda_c_trim = lambda_c_trim[height_id,:,:]
    mu_c_trim = mu_c_trim[height_id,:,:]
    q_gt_100um_trim = q_gt_100um_trim[height_id,:,:]
    N_gt_100um_trim = N_gt_100um_trim[height_id,:,:]


    #------------------------------------------
    # Identify profiles where CTT > -25 deg C to isolate
    # cumulus and congestus profiles. Resulting arrays will
    # be of shape nz x num_cong_profiles
    #------------------------------------------ 
    nz_trim = len(zamsl_trim[:,0,0])
    #cong_mask = ctt_trim >= -25.
    cong_mask = (ctt_trim >= -25.) & (cth_trim >= 0.5) & (opd_trim > 10.)

    flat_mask = cong_mask.values.flatten()
    zamsl_flat = zamsl_trim.reshape(nz_trim, -1)  # Shape: (47, 66×9) = (47, 594)  
    zamsl_filtered = zamsl_flat[:, flat_mask]  # Shape: (47, X)
    z_agl_flat = z_agl_trim.reshape(nz_trim, -1)
    z_agl_filtered = z_agl_flat[:, flat_mask]
    temp_flat = temp_trim.reshape(nz_trim, -1)
    temp_filtered = temp_flat[:, flat_mask]
    RH_flat = RH_trim.reshape(nz_trim, -1)
    RH_filtered = RH_flat[:, flat_mask]
    qr_flat = qr_trim.reshape(nz_trim, -1)
    qr_filtered = qr_flat[:, flat_mask]
    qc_flat = qc_trim.reshape(nz_trim, -1)
    qc_filtered = qc_flat[:, flat_mask]
    Nr_flat = Nr_trim.reshape(nz_trim, -1)
    Nr_filtered = Nr_flat[:, flat_mask]
    Nc_flat = Nc_trim.reshape(nz_trim, -1)
    Nc_filtered = Nc_flat[:, flat_mask]
    
    D_num_flat = D_num_trim.values.reshape(nz_trim, -1)
    D_num_filtered = D_num_flat[:, flat_mask]
    D_vol_flat = D_vol_trim.values.reshape(nz_trim, -1)
    D_vol_filtered = D_vol_flat[:, flat_mask]
    D_mass_flat = D_mass_trim.values.reshape(nz_trim, -1)
    D_mass_filtered = D_mass_flat[:, flat_mask]
    mmd_flat = mmd_trim.values.reshape(nz_trim, -1)
    mmd_filtered = mmd_flat[:, flat_mask]
    N_flat = N_trim.values.reshape(nz_trim, -1)
    N_filtered = N_flat[:, flat_mask]
    q_flat = q_trim.values.reshape(nz_trim, -1)
    q_filtered = q_flat[:, flat_mask]
    rho_air_flat = rho_air_trim.values.reshape(nz_trim, -1)
    rho_air_filtered = rho_air_flat[:, flat_mask]
    #sigma_num_flat = sigma_num_trim.values.reshape(nz_trim, -1)
    #sigma_num_filtered = sigma_num_flat[:, flat_mask]
    #skew_num_flat = skew_num_trim.values.reshape(nz_trim, -1)
    #skew_num_filtered = skew_num_flat[:, flat_mask]
    #kurt_num_flat = kurt_num_trim.values.reshape(nz_trim, -1)
    #kurt_num_filtered = kurt_num_flat[:, flat_mask]
    #sigma_mass_flat = sigma_mass_trim.values.reshape(nz_trim, -1)
    #sigma_mass_filtered = sigma_mass_flat[:, flat_mask]
    #skew_mass_flat = skew_mass_trim.values.reshape(nz_trim, -1)
    #skew_mass_filtered = skew_mass_flat[:, flat_mask]
    #kurt_mass_flat = kurt_mass_trim.values.reshape(nz_trim, -1)
    #kurt_mass_filtered = kurt_mass_flat[:, flat_mask]
    N_0_r_flat = N_0_r_trim.values.reshape(nz_trim, -1)
    N_0_r_filtered = N_0_r_flat[:, flat_mask]
    N_0_c_flat = N_0_c_trim.values.reshape(nz_trim, -1)
    N_0_c_filtered = N_0_c_flat[:, flat_mask]
    lambda_r_flat = lambda_r_trim.values.reshape(nz_trim, -1)
    lambda_r_filtered = lambda_r_flat[:, flat_mask]
    lambda_c_flat = lambda_c_trim.values.reshape(nz_trim, -1)
    lambda_c_filtered = lambda_c_flat[:, flat_mask]
    mu_c_flat = mu_c_trim.values.reshape(nz_trim, -1)
    mu_c_filtered = mu_c_flat[:, flat_mask]
    q_gt_100um_flat = q_gt_100um_trim.values.reshape(nz_trim, -1)
    q_gt_100um_filtered = q_gt_100um_flat[:, flat_mask]
    N_gt_100um_flat = N_gt_100um_trim.values.reshape(nz_trim, -1)
    N_gt_100um_filtered = N_gt_100um_flat[:, flat_mask]

    ctt_flat = ctt_trim.values.flatten()
    ctt_filtered = ctt_flat[flat_mask]  # Shape: (X,)
    cth_flat = cth_trim.values.flatten()
    cth_filtered = cth_flat[flat_mask]  
    opd_flat = opd_trim.values.flatten()
    opd_filtered = opd_flat[flat_mask]  
    lwp_flat = lwp_trim.values.flatten()
    lwp_filtered = lwp_flat[flat_mask]  
    twp_flat = twp_trim.values.flatten()
    twp_filtered = twp_flat[flat_mask] 
    iwp_flat = iwp_trim.values.flatten()
    iwp_filtered = iwp_flat[flat_mask] 
    
    #---------------------------------------------------
    # Now limit to points w/ total LWC > 1.e-3 g/m^3
    #---------------------------------------------------
    lwc_filtered = q_filtered*rho_air_filtered*1.e3 # g/m^3
    valid_mask = (lwc_filtered > 1.e-3) & (temp_filtered >= 0.)
    if np.size(valid_mask) == 0.:
        print('No congestus ID points w/ LWC > 1.e-3 g/m^3.')
        continue

    lwc_valid = lwc_filtered[valid_mask]
    temp_valid = temp_filtered[valid_mask]
    RH_valid = RH_filtered[valid_mask]
    D_num_valid = D_num_filtered[valid_mask]
    D_vol_valid = D_vol_filtered[valid_mask]
    D_mass_valid = D_mass_filtered[valid_mask]
    mmd_valid = mmd_filtered[valid_mask]
    N_valid = N_filtered[valid_mask]
    q_valid = q_filtered[valid_mask]
    rho_air_valid = rho_air_filtered[valid_mask]
    #sigma_num_valid = sigma_num_filtered[valid_mask]
    #skew_num_valid = skew_num_filtered[valid_mask]
    #kurt_num_valid = kurt_num_filtered[valid_mask]
    #sigma_mass_valid = sigma_mass_filtered[valid_mask]
    #skew_mass_valid = skew_mass_filtered[valid_mask]
    #kurt_mass_valid = kurt_mass_filtered[valid_mask]
    N_0_r_valid = N_0_r_filtered[valid_mask]
    N_0_c_valid = N_0_c_filtered[valid_mask]
    lambda_r_valid = lambda_r_filtered[valid_mask]
    lambda_c_valid = lambda_c_filtered[valid_mask]
    mu_c_valid = mu_c_filtered[valid_mask]
    q_gt_100um_valid = q_gt_100um_filtered[valid_mask]
    N_gt_100um_valid = N_gt_100um_filtered[valid_mask]
    qr_valid = qr_filtered[valid_mask]
    Nr_valid = Nr_filtered[valid_mask]
    qc_valid = qc_filtered[valid_mask]
    Nc_valid = Nc_filtered[valid_mask]
    z_agl_valid = z_agl_filtered[valid_mask]
    zamsl_valid = zamsl_filtered[valid_mask]
    
    save_path = '/pscratch/sd/m/mckenna/cacti/wrf/temp_cong_dsd_params/'
    str_dt = dsd_datetime.strftime('%Y%m%d_%H:%M:%S')
    np.savez(save_path+"cong_dsd_params_"+str_dt+".npz",\
                            z_agl=z_agl_valid,\
                            zamsl=zamsl_valid,\
                            temp=temp_valid,\
                            RH=RH_valid,\
                            lwc=lwc_valid,\
                            D_num=D_num_valid,\
                            D_vol=D_vol_valid,\
                            D_mass=D_mass_valid,\
                            mmd=mmd_valid,\
                            N=N_valid,\
                            q=q_valid,\
                            rho_air=rho_air_valid,\
                            #sigma_num=sigma_num_valid,\
                            #skew_num=skew_num_valid,\
                            #kurt_num=kurt_num_valid,\
                            #sigma_mass=sigma_mass_valid,\
                            #skew_mass=skew_mass_valid,\
                            #kurt_mass=kurt_mass_valid,\
                            N_0_r=N_0_r_valid,\
                            N_0_c=N_0_c_valid,\
                            lambda_r=lambda_r_valid,\
                            lambda_c=lambda_c_valid,\
                            mu_c=mu_c_valid,\
                            q_gt_100um=q_gt_100um_valid,\
                            N_gt_100um=N_gt_100um_valid,\
                            qr=qr_valid,\
                            qc=qc_valid,\
                            Nr=Nr_valid,\
                            Nc=Nc_valid,\
                            )
    #break
    #print(aaaaaaa)

    print('')
print('done')
# Out:
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181123_04:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181123_04:45:00.nc
# CT datetime: 2018-11-23 04:45:00+00:00
# DSD datetime: 2018-11-23 04:45:00+00:00
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 189
#     186 ds_3d.close()
#     188 # Calculate RH
# --> 189 print(aaaaaa)
#     192 temp = subset_var_3d(temp,csapr_mask)
#     193 qr = subset_var_3d(qr,csapr_mask)
#
# NameError: name 'aaaaaa' is not defined

# %%
print(np.shape(temp.values),np.max(temp.values),np.min(temp.values))
print(np.shape(pres.values),np.max(pres.values),np.min(pres.values))
print(np.shape(qv.values),np.max(qv.values),np.min(qv.values))
# Out:
# (80, 499, 599) 298.98404 -999.0
# (80, 499, 599) 99844.6 -999.0
# (80, 499, 599) 0.010867245 -0.9990001

# %%
C0 = 0.611583699e3
C1 = 0.444606896e2
C2 = 0.143177157e1
C3 = 0.264224321e-1
C4 = 0.299291081e-3
C5 = 0.203154182e-5
C6 = 0.702620698e-8
C7 = 0.379534310e-11
C8 = -0.321582393e-13
X = temp.values - 273.16 # temperature in deg C
ESL = C0 + X*(C1 + X*(C2 + X*(C3 + X*(C4 + X*(C5 + X*(C6 + X*(C7 + X*C8))))))) #saturation vapor pressure
QVS = 0.622*ESL/(pres.values - ESL) #saturation vapor mixing ratio
RH = 1e2*qv.values/QVS # %

# %%
np.min(RH)
# Out:
# 0.20952246

# %%
print(np.nanmax(ctt_trim.values))
print(np.nanmin(ctt_trim.values))
print(np.nanmax(opd_trim.values))
print(np.nanmin(opd_trim.values))
print(np.nanmax(cth_trim.values))
print(np.nanmin(cth_trim.values))

# %%
#for ii in range(3100,num_ct_files):
#for ii in range(3650,num_ct_files):
#for ii in range(3660,num_ct_files):

#for ii in range(num_ct_files):
#for ii in range(3600,3700):
def driver_func(ct_file,dsd_file,wrf_3d_files):

    #ct_file = ct_files[ii]
    #dsd_file = dsd_files[ii]
    print('CT file:',ct_file)
    print('DSD file:',dsd_file)
    ct_str = ct_file.split('/')[-1].split('.')[-2].split('_')[-2:]
    ct_date_str = ct_str[0]
    ct_time_str = ct_str[1].split(':')
    ct_year = int(ct_date_str[0:4])
    ct_month = int(ct_date_str[4:6])
    ct_day = int(ct_date_str[6:8])
    ct_hour = int(ct_time_str[0])
    ct_min = int(ct_time_str[1])
    ct_sec = int(ct_time_str[2])
    ct_datetime = datetime.datetime(ct_year,ct_month,ct_day,ct_hour,ct_min,ct_sec,tzinfo=datetime.timezone.utc)
    
    dsd_str = dsd_file.split('/')[-1].split('.')[-2].split('_')[-2:]
    dsd_date_str = dsd_str[0]
    dsd_time_str = dsd_str[1].split(':')
    dsd_year = int(dsd_date_str[0:4])
    dsd_month = int(dsd_date_str[4:6])
    dsd_day = int(dsd_date_str[6:8])
    dsd_hour = int(dsd_time_str[0])
    dsd_min = int(dsd_time_str[1])
    dsd_sec = int(dsd_time_str[2])
    dsd_datetime = datetime.datetime(dsd_year,dsd_month,dsd_day,dsd_hour,dsd_min,dsd_sec,tzinfo=datetime.timezone.utc)
    #print('CT datetime:',ct_datetime)
    #print('DSD datetime:',dsd_datetime)
    #print('Time:',dsd_datetime)

    if ct_datetime != dsd_datetime:
        raise RuntimeError('Times between cloud-top file and DSD file do not match...')


    static = np.load("static_vars.npz")
    z_agl = static["z_agl"]
    csapr_nan_mask = static['csapr_nan_mask']
    #zamsl = static["zamsl"]
    #csapr_mask = static["csapr_mask"]
    #lon_2d = static["lon_2d"]
    #lat_2d = static["lat_2d"]
    
    
    ds_ct = xr.open_dataset(ct_file)
    cth = ds_ct['cth_tau_ir'].values 
    cth = cth + (ter_hgt*1.e-3) # CTH was calculated using height AGL, but actually needs to be AMSL, so adding it back here
    #==============================================================================
    # Skip file entirely if entirely absent of cloud
    #==============================================================================
    if np.isnan(np.nanmax(cth)):
        ds_ct.close()
        print('Skipping file because no cloud present.')
        return
    ctt = ds_ct['ctt_tau_ir'] 
    #==============================================================================
    # Skip file if the warmest CTT in the entire domain is colder than -25 deg C.
    #==============================================================================
    if np.nanmax(ctt) < -25.:
        ds_ct.close()
        print('Skipping file because warmest CTT is colder than -25 deg C.')
        return
    lon = ds_ct['lon']
    lat = ds_ct['lat']
    ctt_dim = 2
    ctt_trim = trim_var(lon,lat,ctt,2)
    lon_trim = trim_var(lon,lat,lon,2)
    lat_trim = trim_var(lon,lat,lat,2)
    #==============================================================================
    # Skip file if warmest CTT in the trimmed domain is colder than -25 deg C.
    #==============================================================================
    if (np.nanmax(ctt_trim) < -25.) or (np.isnan(np.nanmax(ctt_trim))):
        ds_ct.close()
        print('Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.')
        return
        
    # Read in other variables to be used for filtering
    lwp = ds_ct['lwp']
    twp = ds_ct['twp']
    iwp = ds_ct['iwp']
    opd = ds_ct['opd_vis']

    # Trim them
    lwp_trim = trim_var(lon,lat,lwp,2)
    twp_trim = trim_var(lon,lat,twp,2)
    iwp_trim = trim_var(lon,lat,iwp,2)
    opd_trim = trim_var(lon,lat,opd,2)
    cth_trim = trim_var(lon,lat,cth,2)
    ds_ct.close()

    #==============================================================================
    #==============================================================================
    # Now extract DSD parameters
    #==============================================================================
    #==============================================================================
    ds_dsd = xr.open_dataset(dsd_file)
    D_num = ds_dsd['D_num'] # m
    D_vol = ds_dsd['D_vol'] # m
    D_mass = ds_dsd['D_mass'] # m
    mmd = ds_dsd['mmd'] # m
    N = ds_dsd['N'] # kg^-1
    q = ds_dsd['q'] # kg/kg
    rho_air = ds_dsd['rho_air'] # kg/m^3
    #sigma_num = ds_dsd['sigma_num'] # m
    #skew_num = ds_dsd['skew_num'] # unitless
    #kurt_num = ds_dsd['kurt_num'] # unitless
    #sigma_mass = ds_dsd['sigma_mass'] # m
    #skew_mass = ds_dsd['skew_mass'] # unitless
    #kurt_mass = ds_dsd['kurt_mass'] # unitless
    N_0_r = ds_dsd['N_0_r'] # m^-4
    N_0_c = ds_dsd['N_0_c'] # m^-4
    lambda_r = ds_dsd['lambda_r'] # m^-1
    lambda_c = ds_dsd['lambda_c'] # m^-1
    mu_c = ds_dsd['mu_c'] # unitless
    q_gt_100um = ds_dsd['q_gt_100um'] # kg/kg
    N_gt_100um = ds_dsd['N_gt_100um'] # kg^-1
    ds_dsd.close()

    # NaN-out values that lie outside the CSAPR range
    D_num = D_num.where(~csapr_nan_mask)
    D_vol = D_vol.where(~csapr_nan_mask)
    D_mass = D_mass.where(~csapr_nan_mask)
    mmd = mmd.where(~csapr_nan_mask)
    N = N.where(~csapr_nan_mask)
    q = q.where(~csapr_nan_mask)
    rho_air = rho_air.where(~csapr_nan_mask)
    #sigma_num = sigma_num.where(~csapr_nan_mask)
    #skew_num = skew_num.where(~csapr_nan_mask)
    #kurt_num = kurt_num.where(~csapr_nan_mask)
    #sigma_mass = sigma_mass.where(~csapr_nan_mask)
    #skew_mass = skew_mass.where(~csapr_nan_mask)
    #kurt_mass = kurt_mass.where(~csapr_nan_mask)
    N_0_r = N_0_r.where(~csapr_nan_mask)
    N_0_c = N_0_c.where(~csapr_nan_mask)
    lambda_r = lambda_r.where(~csapr_nan_mask)
    lambda_c = lambda_c.where(~csapr_nan_mask)
    mu_c = mu_c.where(~csapr_nan_mask)
    q_gt_100um = q_gt_100um.where(~csapr_nan_mask)
    N_gt_100um = N_gt_100um.where(~csapr_nan_mask)

    D_num_trim = trim_var(lon,lat,D_num,3)
    D_vol_trim = trim_var(lon,lat,D_vol,3)
    D_mass_trim = trim_var(lon,lat,D_mass,3)
    mmd_trim = trim_var(lon,lat,mmd,3)
    N_trim = trim_var(lon,lat,N,3)
    q_trim = trim_var(lon,lat,q,3)
    rho_air_trim = trim_var(lon,lat,rho_air,3)
    #sigma_num_trim = trim_var(lon,lat,sigma_num,3)
    #skew_num_trim = trim_var(lon,lat,skew_num,3)
    #kurt_num_trim = trim_var(lon,lat,kurt_num,3)
    #sigma_mass_trim = trim_var(lon,lat,sigma_mass,3)
    #skew_mass_trim = trim_var(lon,lat,skew_mass,3)
    #kurt_mass_trim = trim_var(lon,lat,kurt_mass,3)
    N_0_r_trim = trim_var(lon,lat,N_0_r,3)
    N_0_c_trim = trim_var(lon,lat,N_0_c,3)
    lambda_r_trim = trim_var(lon,lat,lambda_r,3)
    lambda_c_trim = trim_var(lon,lat,lambda_c,3)
    mu_c_trim = trim_var(lon,lat,mu_c,3)
    q_gt_100um_trim = trim_var(lon,lat,q_gt_100um,3)
    N_gt_100um_trim = trim_var(lon,lat,N_gt_100um,3)

    #------------------------------------------
    # Get temperature
    # Also get Qr, Qc. Don't actually need these,
    # but they're helpful conceptually during testing.
    #------------------------------------------
    time_id = np.where(wrf_3d_datetimes == ct_datetime)
    if np.size(time_id) > 0.:
        time_id = time_id[0][0]
    else:
        raise RuntimeError('No matchting WRF 3D file.')
    ds_3d = xr.open_dataset(wrf_3d_files[time_id])
    temp = ds_3d['CAC_T'].squeeze() # K
    qr = ds_3d['CAC_QR'].squeeze()*1.e-3 # kg/kg
    qc = ds_3d['CAC_QC'].squeeze()*1.e-3 # kg/kg
    Nr = ds_3d['CAC_NR'].squeeze()*1.e-3 # /kg
    Nc = ds_3d['CAC_NC'].squeeze()*1.e-3 # /kg
    qv = ds_3d['CAC_QV'].squeeze()*1.e-3 # kg/kg
    pres = ds_3d['CAC_P'].squeeze() # Pa
    ds_3d.close()

    # Calculate RH
    C0 = 0.611583699e3
    C1 = 0.444606896e2
    C2 = 0.143177157e1
    C3 = 0.264224321e-1
    C4 = 0.299291081e-3
    C5 = 0.203154182e-5
    C6 = 0.702620698e-8
    C7 = 0.379534310e-11
    C8 = -0.321582393e-13
    X = temp.values - 273.15 # temperature in deg C
    ESL = C0 + X*(C1 + X*(C2 + X*(C3 + X*(C4 + X*(C5 + X*(C6 + X*(C7 + X*C8))))))) #saturation vapor pressure
    QVS = 0.622*ESL/(pres.values - ESL) #saturation vapor mixing ratio
    RH = 1e2*qv.values/QVS # %


    
    temp = subset_var_3d(temp,csapr_mask)
    RH = subset_var_3d(RH,csapr_mask)
    qr = subset_var_3d(qr,csapr_mask)
    qc = subset_var_3d(qc,csapr_mask)
    Nr = subset_var_3d(Nr,csapr_mask)
    Nc = subset_var_3d(Nc,csapr_mask)
    qr[:,csapr_nan_mask] = np.nan
    Nr[:,csapr_nan_mask] = np.nan
    qc[:,csapr_nan_mask] = np.nan
    Nc[:,csapr_nan_mask] = np.nan
    temp_trim = trim_var(lon,lat,temp,3)-273.15
    RH_trim = trim_var(lon,lat,RH,3)
    qr_trim = trim_var(lon,lat,qr,3)
    Nr_trim = trim_var(lon,lat,Nr,3)
    qc_trim = trim_var(lon,lat,qc,3)
    Nc_trim = trim_var(lon,lat,Nc,3)
    zamsl_trim = trim_var(lon,lat,zamsl,3)
    z_agl_trim = trim_var(lon,lat,z_agl,3)


    #------------------------------------------
    # Limit profiles to be under 10 km, as a start to limit memory
    #------------------------------------------
    zamsl_mean = np.mean(zamsl_trim,axis=(1,2))
    temp_mean = np.mean(temp_trim,axis=(1,2))
    height_id = np.where(zamsl_mean < 10000.)[0]

    temp_trim = temp_trim[height_id,:,:]
    RH_trim = RH_trim[height_id,:,:]
    qr_trim = qr_trim[height_id,:,:]
    Nr_trim = Nr_trim[height_id,:,:]
    qc_trim = qc_trim[height_id,:,:]
    Nc_trim = Nc_trim[height_id,:,:]
    zamsl_trim = zamsl_trim[height_id,:,:]
    z_agl_trim = z_agl_trim[height_id,:,:]
    D_num_trim = D_num_trim[height_id,:,:]
    D_vol_trim = D_vol_trim[height_id,:,:]
    D_mass_trim = D_mass_trim[height_id,:,:]
    mmd_trim = mmd_trim[height_id,:,:]
    N_trim = N_trim[height_id,:,:]
    q_trim = q_trim[height_id,:,:]
    rho_air_trim = rho_air_trim[height_id,:,:]
    #sigma_num_trim = sigma_num_trim[height_id,:,:]
    #skew_num_trim = skew_num_trim[height_id,:,:]
    #kurt_num_trim = kurt_num_trim[height_id,:,:]
    #sigma_mass_trim = sigma_mass_trim[height_id,:,:]
    #skew_mass_trim = skew_mass_trim[height_id,:,:]
    #kurt_mass_trim = kurt_mass_trim[height_id,:,:]
    N_0_r_trim = N_0_r_trim[height_id,:,:]
    N_0_c_trim = N_0_c_trim[height_id,:,:]
    lambda_r_trim = lambda_r_trim[height_id,:,:]
    lambda_c_trim = lambda_c_trim[height_id,:,:]
    mu_c_trim = mu_c_trim[height_id,:,:]
    q_gt_100um_trim = q_gt_100um_trim[height_id,:,:]
    N_gt_100um_trim = N_gt_100um_trim[height_id,:,:]


    #------------------------------------------
    # Identify profiles where CTT > -25 deg C to isolate
    # cumulus and congestus profiles. Resulting arrays will
    # be of shape nz x num_cong_profiles
    #------------------------------------------ 
    nz_trim = len(zamsl_trim[:,0,0])
    #cong_mask = ctt_trim >= -25.
    cong_mask = (ctt_trim >= -25.) & (cth_trim >= 0.5) & (opd_trim > 10.)

    flat_mask = cong_mask.values.flatten()
    zamsl_flat = zamsl_trim.reshape(nz_trim, -1)  # Shape: (47, 66×9) = (47, 594)  
    zamsl_filtered = zamsl_flat[:, flat_mask]  # Shape: (47, X)
    z_agl_flat = z_agl_trim.reshape(nz_trim, -1)
    z_agl_filtered = z_agl_flat[:, flat_mask]
    temp_flat = temp_trim.reshape(nz_trim, -1)
    temp_filtered = temp_flat[:, flat_mask]
    RH_flat = RH_trim.reshape(nz_trim, -1)
    RH_filtered = RH_flat[:, flat_mask]
    qr_flat = qr_trim.reshape(nz_trim, -1)
    qr_filtered = qr_flat[:, flat_mask]
    qc_flat = qc_trim.reshape(nz_trim, -1)
    qc_filtered = qc_flat[:, flat_mask]
    Nr_flat = Nr_trim.reshape(nz_trim, -1)
    Nr_filtered = Nr_flat[:, flat_mask]
    Nc_flat = Nc_trim.reshape(nz_trim, -1)
    Nc_filtered = Nc_flat[:, flat_mask]
    
    D_num_flat = D_num_trim.values.reshape(nz_trim, -1)
    D_num_filtered = D_num_flat[:, flat_mask]
    D_vol_flat = D_vol_trim.values.reshape(nz_trim, -1)
    D_vol_filtered = D_vol_flat[:, flat_mask]
    D_mass_flat = D_mass_trim.values.reshape(nz_trim, -1)
    D_mass_filtered = D_mass_flat[:, flat_mask]
    mmd_flat = mmd_trim.values.reshape(nz_trim, -1)
    mmd_filtered = mmd_flat[:, flat_mask]
    N_flat = N_trim.values.reshape(nz_trim, -1)
    N_filtered = N_flat[:, flat_mask]
    q_flat = q_trim.values.reshape(nz_trim, -1)
    q_filtered = q_flat[:, flat_mask]
    rho_air_flat = rho_air_trim.values.reshape(nz_trim, -1)
    rho_air_filtered = rho_air_flat[:, flat_mask]
    #sigma_num_flat = sigma_num_trim.values.reshape(nz_trim, -1)
    #sigma_num_filtered = sigma_num_flat[:, flat_mask]
    #skew_num_flat = skew_num_trim.values.reshape(nz_trim, -1)
    #skew_num_filtered = skew_num_flat[:, flat_mask]
    #kurt_num_flat = kurt_num_trim.values.reshape(nz_trim, -1)
    #kurt_num_filtered = kurt_num_flat[:, flat_mask]
    #sigma_mass_flat = sigma_mass_trim.values.reshape(nz_trim, -1)
    #sigma_mass_filtered = sigma_mass_flat[:, flat_mask]
    #skew_mass_flat = skew_mass_trim.values.reshape(nz_trim, -1)
    #skew_mass_filtered = skew_mass_flat[:, flat_mask]
    #kurt_mass_flat = kurt_mass_trim.values.reshape(nz_trim, -1)
    #kurt_mass_filtered = kurt_mass_flat[:, flat_mask]
    N_0_r_flat = N_0_r_trim.values.reshape(nz_trim, -1)
    N_0_r_filtered = N_0_r_flat[:, flat_mask]
    N_0_c_flat = N_0_c_trim.values.reshape(nz_trim, -1)
    N_0_c_filtered = N_0_c_flat[:, flat_mask]
    lambda_r_flat = lambda_r_trim.values.reshape(nz_trim, -1)
    lambda_r_filtered = lambda_r_flat[:, flat_mask]
    lambda_c_flat = lambda_c_trim.values.reshape(nz_trim, -1)
    lambda_c_filtered = lambda_c_flat[:, flat_mask]
    mu_c_flat = mu_c_trim.values.reshape(nz_trim, -1)
    mu_c_filtered = mu_c_flat[:, flat_mask]
    q_gt_100um_flat = q_gt_100um_trim.values.reshape(nz_trim, -1)
    q_gt_100um_filtered = q_gt_100um_flat[:, flat_mask]
    N_gt_100um_flat = N_gt_100um_trim.values.reshape(nz_trim, -1)
    N_gt_100um_filtered = N_gt_100um_flat[:, flat_mask]

    ctt_flat = ctt_trim.values.flatten()
    ctt_filtered = ctt_flat[flat_mask]  # Shape: (X,)
    cth_flat = cth_trim.flatten()
    cth_filtered = cth_flat[flat_mask]  
    opd_flat = opd_trim.values.flatten()
    opd_filtered = opd_flat[flat_mask]  
    lwp_flat = lwp_trim.values.flatten()
    lwp_filtered = lwp_flat[flat_mask]  
    twp_flat = twp_trim.values.flatten()
    twp_filtered = twp_flat[flat_mask] 
    iwp_flat = iwp_trim.values.flatten()
    iwp_filtered = iwp_flat[flat_mask] 
    
    #---------------------------------------------------
    # Now limit to points w/ total LWC > 1.e-3 g/m^3
    #---------------------------------------------------
    lwc_filtered = q_filtered*rho_air_filtered*1.e3 # g/m^3
    valid_mask = (lwc_filtered > 1.e-3) & (temp_filtered >= 0.)
    if np.size(valid_mask) == 0.:
        print('No congestus ID points w/ LWC > 1.e-3 g/m^3.')
        return

    lwc_valid = lwc_filtered[valid_mask]
    temp_valid = temp_filtered[valid_mask]
    RH_valid = RH_filtered[valid_mask]
    D_num_valid = D_num_filtered[valid_mask]
    D_vol_valid = D_vol_filtered[valid_mask]
    D_mass_valid = D_mass_filtered[valid_mask]
    mmd_valid = mmd_filtered[valid_mask]
    N_valid = N_filtered[valid_mask]
    q_valid = q_filtered[valid_mask]
    rho_air_valid = rho_air_filtered[valid_mask]
    #sigma_num_valid = sigma_num_filtered[valid_mask]
    #skew_num_valid = skew_num_filtered[valid_mask]
    #kurt_num_valid = kurt_num_filtered[valid_mask]
    #sigma_mass_valid = sigma_mass_filtered[valid_mask]
    #skew_mass_valid = skew_mass_filtered[valid_mask]
    #kurt_mass_valid = kurt_mass_filtered[valid_mask]
    N_0_r_valid = N_0_r_filtered[valid_mask]
    N_0_c_valid = N_0_c_filtered[valid_mask]
    lambda_r_valid = lambda_r_filtered[valid_mask]
    lambda_c_valid = lambda_c_filtered[valid_mask]
    mu_c_valid = mu_c_filtered[valid_mask]
    q_gt_100um_valid = q_gt_100um_filtered[valid_mask]
    N_gt_100um_valid = N_gt_100um_filtered[valid_mask]
    qr_valid = qr_filtered[valid_mask]
    Nr_valid = Nr_filtered[valid_mask]
    qc_valid = qc_filtered[valid_mask]
    Nc_valid = Nc_filtered[valid_mask]
    z_agl_valid = z_agl_filtered[valid_mask]
    zamsl_valid = zamsl_filtered[valid_mask]
    
    save_path = '/pscratch/sd/m/mckenna/cacti/wrf/temp_cong_dsd_params/'
    str_dt = dsd_datetime.strftime('%Y%m%d_%H:%M:%S')
    outname = save_path+"cong_dsd_params_"+str_dt+".npz"
    np.savez(outname,\
                z_agl=z_agl_valid,\
                zamsl=zamsl_valid,\
                temp=temp_valid,\
                RH=RH_valid,\
                lwc=lwc_valid,\
                D_num=D_num_valid,\
                D_vol=D_vol_valid,\
                D_mass=D_mass_valid,\
                mmd=mmd_valid,\
                N=N_valid,\
                q=q_valid,\
                rho_air=rho_air_valid,\
                #sigma_num=sigma_num_valid,\
                #skew_num=skew_num_valid,\
                #kurt_num=kurt_num_valid,\
                #sigma_mass=sigma_mass_valid,\
                #skew_mass=skew_mass_valid,\
                #kurt_mass=kurt_mass_valid,\
                N_0_r=N_0_r_valid,\
                N_0_c=N_0_c_valid,\
                lambda_r=lambda_r_valid,\
                lambda_c=lambda_c_valid,\
                mu_c=mu_c_valid,\
                q_gt_100um=q_gt_100um_valid,\
                N_gt_100um=N_gt_100um_valid,\
                qr=qr_valid,\
                qc=qc_valid,\
                Nr=Nr_valid,\
                Nc=Nc_valid,\
                )
    
    return outname

# %%
# %%time
#dumid = 3100
for dumid in range(205,250):
    print(dumid)
    dum = driver_func(ct_files[dumid],dsd_files[dumid],wrf_3d_files)
# Out:
# 205
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181017_03:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181017_03:15:00.nc
# 206
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181017_03:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181017_03:30:00.nc
# 207
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181017_03:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181017_03:45:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# 208
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181017_04:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181017_04:00:00.nc
# 209
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181017_04:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181017_04:15:00.nc
# 2026-03-13 17:33:50,674 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56098 remote=tcp://127.0.0.1:39321>: Stream is closed
# 2026-03-13 17:33:50,697 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56124 remote=tcp://127.0.0.1:39321>: Stream is closed
# 2026-03-13 17:33:50,698 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56114 remote=tcp://127.0.0.1:39321>: Stream is closed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:4
#
# Cell In[32], line 182, in driver_func(ct_file, dsd_file, wrf_3d_files)
#     180 qr = ds_3d['CAC_QR'].squeeze()*1.e-3 # kg/kg
#     181 qc = ds_3d['CAC_QC'].squeeze()*1.e-3 # kg/kg
# --> 182 Nr = ds_3d['CAC_NR'].squeeze()*1.e-3 # /kg
#     183 Nc = ds_3d['CAC_NC'].squeeze()*1.e-3 # /kg
#     184 qv = ds_3d['CAC_QV'].squeeze()*1.e-3 # kg/kg
#
# File /global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/xarray/core/_typed_ops.py:252, in DataArrayOpsMixin.__mul__(self, other)
#     251 def __mul__(self, other: DaCompatible) -> Self:
# --> 252     return self._binary_op(other, operator.mul)
#
# File /global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/xarray/core/dataarray.py:4744, in DataArray._binary_op(self, other, f, reflexive)
#    4740 other_variable_or_arraylike: DaCompatible = getattr(other, "variable", other)
#    4741 other_coords = getattr(other, "coords", None)
#    4743 variable = (
# -> 4744     f(self.variable, other_variable_or_arraylike)
#    4745     if not reflexive
#    4746     else f(other_variable_or_arraylike, self.variable)
#    4747 )
#    4748 coords, indexes = self.coords._merge_raw(other_coords, reflexive)
#    4749 name = self._result_name(other)
#
# File /global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/xarray/core/_typed_ops.py:482, in VariableOpsMixin.__mul__(self, other)
#     481 def __mul__(self, other: VarCompatible) -> Self | T_DA:
# --> 482     return self._binary_op(other, operator.mul)
#
# File /global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/xarray/core/variable.py:2313, in Variable._binary_op(self, other, f, reflexive)
#    2311     other_data, self_data, dims = _broadcast_compat_data(other, self)
#    2312 else:
# -> 2313     self_data, other_data, dims = _broadcast_compat_data(self, other)
#    2314 keep_attrs = _get_keep_attrs(default=False)
#    2315 attrs = self._attrs if keep_attrs else None
#
# File /global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/xarray/core/variable.py:2929, in _broadcast_compat_data(self, other)
#    2926     dims = new_self.dims
#    2927 else:
#    2928     # rely on numpy broadcasting rules
# -> 2929     self_data = self.data
#    2930     other_data = other
#    2931     dims = self.dims
#
# File /global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/xarray/core/variable.py:449, in Variable.data(self)
#     447     return self._data
#     448 elif isinstance(self._data, indexing.ExplicitlyIndexed):
# --> 449     return self._data.get_duck_array()
#     450 else:
#     451     return self.values
#
# File /global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/xarray/core/indexing.py:837, in MemoryCachedArray.get_duck_array(self)
#     836 def get_duck_array(self):
# --> 837     self._ensure_cached()
#     838     return self.array.get_duck_array()
#
# File /global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/xarray/core/indexing.py:831, in MemoryCachedArray._ensure_cached(self)
#     830 def _ensure_cached(self):
# --> 831     self.array = as_indexable(self.array.get_duck_array())
#
# File /global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/xarray/core/indexing.py:788, in CopyOnWriteArray.get_duck_array(self)
#     787 def get_duck_array(self):
# --> 788     return self.array.get_duck_array()
#
# File /global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/xarray/core/indexing.py:651, in LazilyIndexedArray.get_duck_array(self)
#     647     array = apply_indexer(self.array, self.key)
#     648 else:
#     649     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     650     # it may wrap a BackendArray so use its __getitem__
# --> 651     array = self.array[self.key]
#     653 # self.array[self.key] is now a numpy array when
#     654 # self.array is a BackendArray subclass
#     655 # and self.key is BasicIndexer((slice(None, None, None),))
#     656 # so we need the explicit check for ExplicitlyIndexed
#     657 if isinstance(array, ExplicitlyIndexed):
#
# File /global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:100, in NetCDF4ArrayWrapper.__getitem__(self, key)
#      99 def __getitem__(self, key):
# --> 100     return indexing.explicit_indexing_adapter(
#     101         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     102     )
#
# File /global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/xarray/core/indexing.py:1015, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     993 """Support explicit indexing by delegating to a raw indexing method.
#     994
#     995 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#    1012 Indexing result, in the form of a duck numpy-array.
#    1013 """
#    1014 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1015 result = raw_indexing_method(raw_key.tuple)
#    1016 if numpy_indices.tuple:
#    1017     # index the loaded np.ndarray
#    1018     indexable = NumpyIndexingAdapter(result)
#
# File /global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:113, in NetCDF4ArrayWrapper._getitem(self, key)
#     111     with self.datastore.lock:
#     112         original_array = self.get_array(needs_lock=False)
# --> 113         array = getitem(original_array, key)
#     114 except IndexError:
#     115     # Catch IndexError in netCDF4 and return a more informative
#     116     # error message.  This is most often called when an unsorted
#     117     # indexer is used before the data is loaded from disk.
#     118     msg = (
#     119         "The indexing operation you are attempting to perform "
#     120         "is not valid on netCDF4.Variable object. Try loading "
#     121         "your data into memory first by calling .load()."
#     122     )
#
# KeyboardInterrupt:
# 2026-03-13 17:33:51,288 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56248 remote=tcp://127.0.0.1:39321>: Stream is closed
# 2026-03-13 17:33:51,288 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56198 remote=tcp://127.0.0.1:39321>: Stream is closed
# 2026-03-13 17:33:51,288 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56082 remote=tcp://127.0.0.1:39321>: Stream is closed
# 2026-03-13 17:33:51,287 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56236 remote=tcp://127.0.0.1:39321>: Stream is closed
# 2026-03-13 17:33:51,290 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56088 remote=tcp://127.0.0.1:39321>: Stream is closed
# 2026-03-13 17:33:51,292 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56154 remote=tcp://127.0.0.1:39321>: Stream is closed
# 2026-03-13 17:33:51,293 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56186 remote=tcp://127.0.0.1:39321>: Stream is closed
# 2026-03-13 17:33:51,294 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56194 remote=tcp://127.0.0.1:39321>: Stream is closed
# 2026-03-13 17:33:51,295 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56172 remote=tcp://127.0.0.1:39321>: Stream is closed
# 2026-03-13 17:33:51,294 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56170 remote=tcp://127.0.0.1:39321>: Stream is closed
# 2026-03-13 17:33:51,296 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56184 remote=tcp://127.0.0.1:39321>: Stream is closed
# 2026-03-13 17:33:51,296 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56204 remote=tcp://127.0.0.1:39321>: Stream is closed
# 2026-03-13 17:33:51,297 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/worker.py", line 1250, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/core.py", line 1015, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/global/common/software/m1657/mckenna/flextrkr/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56228 remote=tcp://127.0.0.1:39321>: Stream is closed

# %%
80*5

# %% [markdown]
# # Dask stuff

# %%
dask.config.config["distributed"]["dashboard"]["link"] = "{JUPYTERHUB_SERVICE_PREFIX}proxy/{host}:{port}/status"

# %%
cluster = LocalCluster(n_workers=80,threads_per_worker=1,memory_limit='5GB')#,dashboard_address=':8787')
client = Client(cluster)

# %%
cluster
# Out:
# LocalCluster(b5ac23ff, 'tcp://127.0.0.1:40567', workers=80, threads=80, memory=372.53 GiB)

# %%
def suppress_warnings():
    import warnings
    warnings.filterwarnings("ignore", message=".*All-NaN axis encountered*", category=UserWarning)
    warnings.filterwarnings("ignore", category=RuntimeWarning)

client.run(suppress_warnings)
# Out:
# {'tcp://127.0.0.1:33587': None,
#  'tcp://127.0.0.1:33611': None,
#  'tcp://127.0.0.1:33629': None,
#  'tcp://127.0.0.1:34057': None,
#  'tcp://127.0.0.1:34091': None,
#  'tcp://127.0.0.1:34193': None,
#  'tcp://127.0.0.1:34305': None,
#  'tcp://127.0.0.1:34483': None,
#  'tcp://127.0.0.1:34625': None,
#  'tcp://127.0.0.1:35203': None,
#  'tcp://127.0.0.1:35327': None,
#  'tcp://127.0.0.1:35531': None,
#  'tcp://127.0.0.1:35711': None,
#  'tcp://127.0.0.1:35727': None,
#  'tcp://127.0.0.1:35735': None,
#  'tcp://127.0.0.1:35843': None,
#  'tcp://127.0.0.1:36119': None,
#  'tcp://127.0.0.1:36165': None,
#  'tcp://127.0.0.1:36673': None,
#  'tcp://127.0.0.1:36723': None,
#  'tcp://127.0.0.1:36725': None,
#  'tcp://127.0.0.1:36869': None,
#  'tcp://127.0.0.1:36973': None,
#  'tcp://127.0.0.1:36985': None,
#  'tcp://127.0.0.1:37673': None,
#  'tcp://127.0.0.1:37735': None,
#  'tcp://127.0.0.1:37879': None,
#  'tcp://127.0.0.1:38103': None,
#  'tcp://127.0.0.1:38307': None,
#  'tcp://127.0.0.1:38325': None,
#  'tcp://127.0.0.1:38439': None,
#  'tcp://127.0.0.1:38785': None,
#  'tcp://127.0.0.1:38927': None,
#  'tcp://127.0.0.1:39453': None,
#  'tcp://127.0.0.1:39499': None,
#  'tcp://127.0.0.1:40223': None,
#  'tcp://127.0.0.1:40459': None,
#  'tcp://127.0.0.1:40549': None,
#  'tcp://127.0.0.1:40557': None,
#  'tcp://127.0.0.1:40797': None,
#  'tcp://127.0.0.1:41029': None,
#  'tcp://127.0.0.1:41115': None,
#  'tcp://127.0.0.1:41425': None,
#  'tcp://127.0.0.1:41533': None,
#  'tcp://127.0.0.1:41713': None,
#  'tcp://127.0.0.1:41737': None,
#  'tcp://127.0.0.1:41861': None,
#  'tcp://127.0.0.1:41955': None,
#  'tcp://127.0.0.1:42049': None,
#  'tcp://127.0.0.1:42187': None,
#  'tcp://127.0.0.1:42271': None,
#  'tcp://127.0.0.1:42559': None,
#  'tcp://127.0.0.1:43183': None,
#  'tcp://127.0.0.1:43221': None,
#  'tcp://127.0.0.1:43223': None,
#  'tcp://127.0.0.1:43279': None,
#  'tcp://127.0.0.1:43493': None,
#  'tcp://127.0.0.1:43553': None,
#  'tcp://127.0.0.1:43631': None,
#  'tcp://127.0.0.1:43921': None,
#  'tcp://127.0.0.1:44147': None,
#  'tcp://127.0.0.1:44185': None,
#  'tcp://127.0.0.1:44187': None,
#  'tcp://127.0.0.1:44351': None,
#  'tcp://127.0.0.1:44545': None,
#  'tcp://127.0.0.1:44569': None,
#  'tcp://127.0.0.1:44727': None,
#  'tcp://127.0.0.1:45157': None,
#  'tcp://127.0.0.1:45359': None,
#  'tcp://127.0.0.1:45409': None,
#  'tcp://127.0.0.1:45443': None,
#  'tcp://127.0.0.1:45473': None,
#  'tcp://127.0.0.1:45927': None,
#  'tcp://127.0.0.1:45931': None,
#  'tcp://127.0.0.1:45989': None,
#  'tcp://127.0.0.1:46021': None,
#  'tcp://127.0.0.1:46131': None,
#  'tcp://127.0.0.1:46249': None,
#  'tcp://127.0.0.1:46585': None,
#  'tcp://127.0.0.1:46701': None}

# %%
# %%time
results = []
start_id = 0
#end_id = 250
end_id = len(ct_files)
for ii in range(start_id,end_id):
    result = dask.delayed(driver_func)(ct_files[ii],dsd_files[ii],wrf_3d_files)
    results.append(result)
# Out:
# CPU times: user 429 ms, sys: 154 ms, total: 582 ms
# Wall time: 465 ms

# %%
# %%time
futures = client.compute(results)  # results is a list of delayed or dask collections
# Out:
# CPU times: user 419 ms, sys: 14.2 ms, total: 433 ms
# Wall time: 428 ms
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181023_19:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181023_19:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181216_08:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181216_08:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181209_04:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181209_04:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190126_10:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190126_10:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190128_17:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190128_17:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181018_03:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181018_03:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190201_14:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190201_14:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181222_19:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181222_19:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181225_09:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181225_09:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181116_16:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181116_16:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181119_07:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181119_07:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181017_15:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181017_15:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190123_15:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190123_15:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181121_16:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181121_16:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181225_18:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181225_18:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181115_19:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181115_19:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181017_12:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181017_12:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181118_00:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181118_00:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190227_08:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190227_08:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190228_01:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190228_01:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181102_13:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181102_13:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190126_08:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190126_08:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190205_20:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190205_20:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181221_21:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181221_21:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181216_17:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181216_17:15:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190205_03:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190205_03:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181210_11:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181210_11:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181204_07:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181204_07:45:00.nc
# Skipping file because warmest CTT is colder than -25 deg C.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190202_15:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190202_15:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181215_10:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181215_10:30:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181028_16:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181028_16:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190228_01:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190228_01:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190205_23:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190205_23:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181019_20:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181019_20:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181021_03:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181021_03:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190302_15:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190302_15:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181208_10:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181208_10:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181128_15:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181128_15:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181225_09:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181225_09:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181225_23:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181225_23:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190225_21:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190225_21:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190201_12:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190201_12:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181016_16:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181016_16:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181015_19:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181015_19:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181207_12:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181207_12:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181216_10:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181216_10:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181115_05:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181115_05:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181127_03:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181127_03:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190225_18:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190225_18:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181125_05:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181125_05:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181125_12:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181125_12:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181225_12:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181225_12:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181223_01:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181223_01:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181024_05:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181024_05:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181030_04:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181030_04:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181219_21:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181219_21:30:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181215_03:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181215_03:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181024_12:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181024_12:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181025_07:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181025_07:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181029_00:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181029_00:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181207_07:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181207_07:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181114_23:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181114_23:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181114_21:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181114_21:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181221_04:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181221_04:30:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190202_23:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190202_23:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181102_14:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181102_14:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181121_23:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181121_23:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190122_11:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190122_11:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181017_14:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181017_14:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181224_06:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181224_06:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181116_03:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181116_03:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190205_16:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190205_16:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181105_09:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181105_09:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181223_10:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181223_10:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190206_09:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190206_09:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181207_01:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181207_01:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190207_19:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190207_19:45:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181124_04:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181124_04:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190302_07:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190302_07:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190303_00:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190303_00:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181028_17:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181028_17:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181208_15:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181208_15:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181030_06:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181030_06:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181216_04:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181216_04:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181226_13:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181226_13:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181224_17:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181224_17:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181210_17:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181210_17:45:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190130_20:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190130_20:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181028_16:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181028_16:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181124_10:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181124_10:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181109_11:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181109_11:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190127_21:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190127_21:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190201_00:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190201_00:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190226_13:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190226_13:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181225_01:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181225_01:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181215_04:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181215_04:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181117_02:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181117_02:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181125_06:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181125_06:45:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181030_08:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181030_08:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181102_18:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181102_18:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181209_08:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181209_08:15:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181117_05:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181117_05:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181015_11:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181015_11:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181018_21:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181018_21:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181201_16:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181201_16:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181128_01:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181128_01:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190224_23:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190224_23:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181107_11:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181107_11:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190205_13:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190205_13:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181115_17:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181115_17:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190128_10:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190128_10:30:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181206_20:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181206_20:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190129_07:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190129_07:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181015_17:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181015_17:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181119_22:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181119_22:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190226_14:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190226_14:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181112_20:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181112_20:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181207_08:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181207_08:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181215_23:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181215_23:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181211_02:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181211_02:45:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190124_09:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190124_09:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190122_17:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190122_17:15:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190206_09:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190206_09:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190129_21:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190129_21:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181117_18:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181117_18:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181208_06:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181208_06:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181223_06:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181223_06:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181207_22:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181207_22:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190206_13:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190206_13:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190124_04:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190124_04:15:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181102_04:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181102_04:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181116_22:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181116_22:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181219_05:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181219_05:00:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181028_14:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181028_14:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181205_08:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181205_08:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190227_20:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190227_20:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181203_20:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181203_20:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181208_02:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181208_02:15:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190204_21:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190204_21:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190228_14:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190228_14:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181210_15:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181210_15:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181210_10:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181210_10:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181220_23:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181220_23:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181127_00:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181127_00:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181201_20:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181201_20:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190127_08:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190127_08:00:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181017_11:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181017_11:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181023_00:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181023_00:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181212_08:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181212_08:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181204_06:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181204_06:45:00.nc
# Skipping file because warmest CTT is colder than -25 deg C.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181208_20:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181208_20:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181108_22:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181108_22:00:00.nc
# Skipping file because warmest CTT is colder than -25 deg C.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181201_03:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181201_03:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181017_11:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181017_11:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181213_13:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181213_13:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190301_23:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190301_23:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181204_07:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181204_07:00:00.nc
# Skipping file because warmest CTT is colder than -25 deg C.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181202_20:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181202_20:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190204_20:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190204_20:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181023_02:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181023_02:45:00.nc
# CT file: CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181127_10:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181127_10:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181017_03:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181017_03:45:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181107_11:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181107_11:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181116_06:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181116_06:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181108_14:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181108_14:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190228_09:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190228_09:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181210_06:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181210_06:15:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181121_18:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181121_18:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181216_22:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181216_22:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181110_23:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181110_23:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190125_09:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190125_09:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181121_00:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181121_00:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181218_12:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181218_12:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181016_02:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181016_02:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190131_12:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190131_12:00:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190122_12:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190122_12:00:00.nc
# Skipping file because warmest CTT is colder than -25 deg C.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190201_12:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190201_12:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181211_09:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181211_09:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181114_20:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181114_20:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181020_01:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181020_01:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181215_20:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181215_20:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181027_07:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181027_07:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190206_08:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190206_08:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190208_15:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190208_15:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190131_16:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190131_16:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190208_18:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190208_18:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181101_12:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181101_12:45:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181111_10:30:00.nc
# ...
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181102_20:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181102_20:15:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181016_15:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181016_15:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181128_14:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181128_14:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181107_01:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181107_01:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181203_12:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181203_12:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181212_06:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181212_06:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181206_12:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181206_12:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181026_00:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181026_00:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181111_04:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181111_04:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190205_19:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190205_19:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181127_12:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181127_12:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181017_10:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181017_10:30:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181112_19:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181112_19:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190301_18:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190301_18:30:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190302_21:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190302_21:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181102_21:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181102_21:45:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190226_23:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190226_23:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181220_11:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181220_11:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181016_17:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181016_17:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181214_20:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181214_20:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181112_01:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181112_01:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181222_02:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181222_02:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181122_21:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181122_21:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181116_13:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181116_13:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181127_04:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181127_04:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181025_02:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181025_02:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181117_06:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181117_06:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181114_05:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181114_05:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190124_22:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190124_22:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181102_22:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181102_22:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190128_08:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190128_08:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181028_23:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181107_04:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181107_04:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181027_00:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181027_00:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181031_07:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181031_07:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190201_15:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190201_15:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181221_12:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181221_12:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190124_23:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190124_23:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190207_08:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190207_08:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190228_02:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190228_02:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181016_12:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181016_12:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181107_23:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181107_23:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181223_19:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181223_19:00:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181221_08:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181221_08:30:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181129_10:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181129_10:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181119_14:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181119_14:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181216_06:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181216_06:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190225_16:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190225_16:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181213_04:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181213_04:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181220_20:30:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181220_20:30:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181209_03:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181209_03:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181129_11:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181129_11:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181122_13:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181122_13:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190301_09:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190301_09:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181206_05:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181206_05:00:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181217_12:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181217_12:45:00.nc
# Skipping file because warmest CTT in trimmed domain is colder than -25 deg C or is NaN.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181114_11:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181114_11:45:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181115_17:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181115_17:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181221_11:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181221_11:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181211_16:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181211_16:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190204_01:45:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190204_01:45:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181225_11:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181225_11:15:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20190128_16:15:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20190128_16:15:00.nc
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181223_10:00:00.nc
# DSD file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km_dsd_parameters/WRF_CACTI_3km_DSD_parameters_liq_only_20181223_10:00:00.nc
# Skipping file because no cloud present.
# CT file: /pscratch/sd/m/mckenna/cacti/wrf/derived_3km/WRF_CACTI_3km_derived_20181116_22:45:00.nc
# DSD file:

# %%
# %%time
print('Step 1')
# Step 1: List .npz files
npz_files = sorted(glob.glob('/pscratch/sd/m/mckenna/cacti/wrf/temp_cong_dsd_params/cong_dsd_params_*.npz'))
print('Step 2')
# Step 2: Get all keys by inspecting the first file
with np.load(npz_files[0]) as sample:
    all_keys = list(sample.keys())
print('Step 3')
# Step 3: Delayed function to load a single file
@delayed
def load_npz_var(filepath, varname):
    with np.load(filepath) as data:
        return data[varname]
print('Step 4')
# Step 4: For each variable, collect delayed arrays and concatenate
def extract_and_concat(varname, file_list):
    delayed_arrays = [load_npz_var(f, varname) for f in file_list]
    return delayed(np.concatenate)(delayed_arrays)
print('Step 5')
# Step 5: Build delayed concatenation for each variable
concatenated_vars = {
    k: extract_and_concat(k, npz_files) for k in all_keys
}
print('Step 6')
# Step 6: Compute in parallel
computed_values = compute(*concatenated_vars.values())
print('Step 7')

# Step 7: Reconstruct dictionary
final_data = dict(zip(concatenated_vars.keys(), computed_values))

# %%
for key,val in final_data.items():
    print(key,np.shape(val),np.nanmax(val),np.nanmin(val))

# %%
fig = plt.figure(figsize=(12,8),constrained_layout=True)
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
Fontsize=11
axlist = [ax1,ax2,ax3,ax4]
for ax in axlist:
    ax.grid(which='both',lw=1,c='dimgrey',ls='dotted')
    ax.tick_params(labelsize=Fontsize)

ax1.hist(ctt_filtered,bins=10,histtype='step',lw=2,color='k',density=True)
ax1.set_xlabel('CTT [$^{\\circ}$C]',fontsize=Fontsize)
ax1.set_ylabel('Probability Density',fontsize=Fontsize)

ax2.hist(cth_filtered*1.e-3,bins=10,histtype='step',lw=2,color='k',density=True)
ax2.set_xlabel('CTH [km]',fontsize=Fontsize)
ax2.set_ylabel('Probability Density',fontsize=Fontsize)

mean_z = np.mean(zamsl_filtered,axis=1)
lwc = qc_filtered*rho_air_filtered*1.e3
clwc = qc_filtered*rho_air_filtered*1.e3
rwc = qr_filtered*rho_air_filtered*1.e3
#lwc[lwc == 0.] = np.nan
mean_lwc = np.nanmean(lwc,axis=1)
mean_clwc = np.nanmean(clwc,axis=1)
mean_rwc = np.nanmean(rwc,axis=1)
ax3.plot(mean_lwc,mean_z*1.e-3,lw=2,c='k',label='Total')
ax3.plot(mean_clwc,mean_z*1.e-3,lw=1.5,c='blue',label='Cloud')
ax3.plot(mean_rwc,mean_z*1.e-3,lw=1.5,c='red',label='Rain')
ax3.set_ylabel('Height [km]',fontsize=Fontsize)
ax3.set_xlabel('Mean LWC [g m$^{-3}$]',fontsize=Fontsize)
ax3.set_ylim(0,5)
ax3.legend(fontsize=Fontsize,loc='best')

mean_D_num = np.nanmean(D_num_filtered*1.e6,axis=1)
mean_D_mass = np.nanmean(D_mass_filtered*1.e6,axis=1)
mean_mmd = np.nanmean(mmd_filtered*1.e6,axis=1)
ax4.plot(mean_D_num,mean_z*1.e-3,lw=2,c='k',label='NWMD')
ax4.plot(mean_D_mass,mean_z*1.e-3,lw=2,c='blue',label='MWMD')
ax4.plot(mean_mmd,mean_z*1.e-3,lw=2,c='red',label='MMD')
ax4.set_ylabel('Height [km]',fontsize=Fontsize)
ax4.set_xlabel('Diameter [$\\mu$m]',fontsize=Fontsize)
ax4.set_ylim(0,5)
ax4.legend(fontsize=Fontsize,loc='best')

ax3.set_xscale('log')
plt.show()
plt.close()

# %%
fig = plt.figure(figsize=(8,6))
ax1 = fig.add_subplot(111)
Fontsize=11
axlist = [ax1]
for ax in axlist:
    ax.tick_params(labelsize=Fontsize)
ax1.contour(lon,lat,ter_hgt,lw=1,colors=['black','dimgrey','grey','lightgrey'],levels=[1000.,1500.,2000.,2500.])
#tmp_plot = ax1.contourf(lon,lat,ctt,levels=np.arange(-25,11,1),cmap='nipy_spectral',extend='both')
tmp_plot = ax1.pcolormesh(lon,lat,ctt,vmin=-5,vmax=5,cmap='RdYlBu_r')
cbar = fig.colorbar(tmp_plot,extend='both')
cbar.ax.set_ylabel('CTT [$^{\\circ}$C]',fontsize=Fontsize)
cbar.ax.tick_params(labelsize=Fontsize)

# Top edge
top_lon = lon_trim[0, :]
top_lat = lat_trim[0, :]

# Bottom edge
bot_lon = lon_trim[-1, :]
bot_lat = lat_trim[-1, :]

# Left edge
left_lon = lon_trim[:, 0]
left_lat = lat_trim[:, 0]

# Right edge
right_lon = lon_trim[:, -1]
right_lat = lat_trim[:, -1]


bbox_lon = np.concatenate([top_lon, right_lon, bot_lon[::-1], left_lon[::-1]])
bbox_lat = np.concatenate([top_lat, right_lat, bot_lat[::-1], left_lat[::-1]])

ax1.plot(bbox_lon, bbox_lat, c='red', lw=2, label='Trim Box')
ax1.legend(fontsize=Fontsize)

plt.show()
plt.close()

# %%
max_mmd = np.nanmax(mmd,axis=(0))
max_D_num = np.nanmax(D_num,axis=(0))
mean_D_num = np.nanmean(D_num,axis=(0))

#csapr_nan_id = np.where(np.isnan(col_max_ref))
#mean_D_num[csapr_nan_id[0],csapr_nan_id[1]] = np.nan

fig = plt.figure(figsize=(8,6))
ax1 = fig.add_subplot(111)
Fontsize=11
axlist = [ax1]
for ax in axlist:
    ax.tick_params(labelsize=Fontsize)
ax1.contour(lon,lat,ter_hgt,lw=1,colors=['black','dimgrey','grey','lightgrey'],levels=[1000.,1500.,2000.,2500.])
#tmp_plot = ax1.pcolormesh(lon,lat,max_mmd*1.e6,cmap='turbo',norm=mpl.colors.LogNorm(vmin=1,vmax=5.e3))
#tmp_plot = ax1.pcolormesh(lon,lat,max_D_num*1.e6,cmap='turbo',vmin=1,vmax=500)
tmp_plot = ax1.pcolormesh(lon,lat,mean_D_num*1.e6,cmap='turbo',vmin=1,vmax=300)
cbar = fig.colorbar(tmp_plot,extend='max')
#cbar.ax.set_ylabel('Col. Max. MMD [$\\mu$m]',fontsize=Fontsize)
#cbar.ax.set_ylabel('Col. Max. NWMD [$\\mu$m]',fontsize=Fontsize)
cbar.ax.set_ylabel('Vertical Avg. NWMD [$\\mu$m]',fontsize=Fontsize)
cbar.ax.tick_params(labelsize=Fontsize)

# Top edge
top_lon = lon_trim[0, :]
top_lat = lat_trim[0, :]

# Bottom edge
bot_lon = lon_trim[-1, :]
bot_lat = lat_trim[-1, :]

# Left edge
left_lon = lon_trim[:, 0]
left_lat = lat_trim[:, 0]

# Right edge
right_lon = lon_trim[:, -1]
right_lat = lat_trim[:, -1]


bbox_lon = np.concatenate([top_lon, right_lon, bot_lon[::-1], left_lon[::-1]])
bbox_lat = np.concatenate([top_lat, right_lat, bot_lat[::-1], left_lat[::-1]])

ax1.plot(bbox_lon, bbox_lat, c='red', lw=2, label='Trim Box')
ax1.legend(fontsize=Fontsize)

plt.show()
plt.close()

# %%
ds_dsd
